# %% [markdown]
# # Complexity Analysis on Radix Sort

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Relationship between number of inputs and number of primitive operations performed

# %% [markdown]
# ### Experiment 1
# - Input Data Type: Integer
# - Random Number Upperbound: 10000
# - Maximum Number of Inputs: 100

# %%
x1= pd.read_csv('NumOfInputs-n_100.csv')
x1
# Out:
#     Number of input, n
# 0                    3
# 1                    6
# 2                    9
# 3                   12
# 4                   15
# 5                   18
# 6                   21
# 7                   24
# 8                   27
# 9                   30
# 10                  33
# 11                  36
# 12                  39
# 13                  42
# 14                  45
# 15                  48
# 16                  51
# 17                  54
# 18                  57
# 19                  60
# 20                  63
# 21                  66
# 22                  69
# 23                  72
# 24                  75
# 25                  78
# 26                  81
# 27                  84
# 28                  87
# 29                  90
# 30                  93
# 31                  96
# 32                  99

# %%
y1= pd.read_csv('NumOfOperations_int-100.csv')
y1
# Out:
#     Number of operation
# 0                   599
# 1                  1661
# 2                  3182
# 3                  5164
# 4                  7605
# 5                 10503
# 6                 13862
# 7                 17676
# 8                 21949
# 9                 26687
# 10                31886
# 11                37542
# 12                43659
# 13                50231
# 14                57266
# 15                64754
# 16                72697
# 17                81099
# 18                89966
# 19                99292
# 20               109083
# 21               119327
# 22               130028
# 23               141190
# 24               152813
# 25               164897
# 26               177436
# 27               190444
# 28               203901
# 29               217815
# 30               232190
# 31               247034
# 32               262325

# %%
# Data Type = Integer
# Upperbound Value = 10000
# Number of Maximum Inputs = 100
plt.title("Number of operation vs n.")
plt.xlabel("Number of input, n")
plt.ylabel("Number of operation")
plt.plot(x1.to_numpy(),y1.to_numpy())
plt.show()

# %% [markdown]
# ### Experiment 2
# - Input Data Type: Integer
# - Random Number Upperbound: 10000
# - Maximum Number of Inputs: 1000

# %%
x2= pd.read_csv('NumOfInputs-n_1000.csv')
x2
# Out:
#      Number of input, n
# 0                     3
# 1                     6
# 2                     9
# 3                    12
# 4                    15
# ..                  ...
# 328                 987
# 329                 990
# 330                 993
# 331                 996
# 332                 999
#
# [333 rows x 1 columns]

# %%
y2= pd.read_csv('NumOfOperations_int-1000.csv')
y2
# Out:
#      Number of operation
# 0                    599
# 1                   1661
# 2                   3182
# 3                   5164
# 4                   7605
# ..                   ...
# 328             24966337
# 329             25117959
# 330             25270042
# 331             25422592
# 332             25575587
#
# [333 rows x 1 columns]

# %%
# Data Type = Integer
# Upperbound Value = 10000
# Number of Maximum Inputs = 1000
plt.title("Number of operation vs n.")
plt.xlabel("Number of input, n")
plt.ylabel("Number of operation")
plt.plot(x2.to_numpy(),y2.to_numpy())
plt.show()

# %% [markdown]
# ### Experiment 3
# - Input Data Type: Integer
# - Random Number Upperbound: 100
# - Maximum Number of Inputs: 1000

# %%
x3= pd.read_csv('NumOfInputs-n_1000.csv')
x3
# Out:
#      Number of input, n
# 0                     3
# 1                     6
# 2                     9
# 3                    12
# 4                    15
# ..                  ...
# 328                 987
# 329                 990
# 330                 993
# 331                 996
# 332                 999
#
# [333 rows x 1 columns]

# %%
y3= pd.read_csv('NumOfOperations_int-1000-upper100.csv')
y3
# Out:
#      Number of operation
# 0                    321
# 1                    837
# 2                   1554
# 3                   2464
# 4                   3569
# ..                   ...
# 328             10628933
# 329             10693413
# 330             10758086
# 331             10822954
# 332             10888025
#
# [333 rows x 1 columns]

# %%
# Data Type = Integer
# Upperbound Value = 100
# Number of Maximum Inputs = 1000
plt.title("Number of operation vs n.")
plt.xlabel("Number of input, n")

plt.ylabel("Number of operation")
plt.plot(x3.to_numpy(),y3.to_numpy())

plt.show()

# %% [markdown]
# ### Experiment 4
# - Input Data Type: Floating Point
# - Random Number Upperbound: 10000
# - Maximum Number of Inputs: 100

# %%
x4= pd.read_csv('NumOfInputs-n_100.csv')
x4
# Out:
#     Number of input, n
# 0                    3
# 1                    6
# 2                    9
# 3                   12
# 4                   15
# 5                   18
# 6                   21
# 7                   24
# 8                   27
# 9                   30
# 10                  33
# 11                  36
# 12                  39
# 13                  42
# 14                  45
# 15                  48
# 16                  51
# 17                  54
# 18                  57
# 19                  60
# 20                  63
# 21                  66
# 22                  69
# 23                  72
# 24                  75
# 25                  78
# 26                  81
# 27                  84
# 28                  87
# 29                  90
# 30                  93
# 31                  96
# 32                  99

# %%
y4= pd.read_csv('NumOfOperations_fp-100.csv')
y4
# Out:
#     Number of operation
# 0                  1278
# 1                  3637
# 2                  7080
# 3                 12680
# 4                 18289
# 5                 24982
# 6                 33692
# 7                 43618
# 8                 53567
# 9                 67247
# 10                82275
# 11                97062
# 12               113066
# 13               130278
# 14               150692
# 15               172453
# 16               195564
# 17               217648
# 18               238422
# 19               262928
# 20               291427
# 21               318362
# 22               349554
# 23               378917
# 24               412803
# 25               448037
# 26               484617
# 27               522544
# 28               557995
# 29               598615
# 30               636489
# 31               675577
# 32               720239

# %%
# Data Type = Floating Point
# Upperbound Value = 10000
# Number of Maximum Inputs = 100
plt.title("Number of operation vs n.")
plt.xlabel("Number of input, n")
plt.ylabel("Number of operation")
plt.plot(x4.to_numpy(),y4.to_numpy())
plt.show()

# %% [markdown]
# ### Experiment 5
# - Input Data Type: Floating Point
# - Random Number Upperbound: 10000
# - Maximum Number of Inputs: 1000

# %%
x5= pd.read_csv('NumOfInputs-n_1000.csv')
x5
# Out:
#      Number of input, n
# 0                     3
# 1                     6
# 2                     9
# 3                    12
# 4                    15
# ..                  ...
# 328                 987
# 329                 990
# 330                 993
# 331                 996
# 332                 999
#
# [333 rows x 1 columns]

# %%
y5= pd.read_csv('NumOfOperations_fp-1000.csv')
y5
# Out:
#      Number of operation
# 0                   1135
# 1                   3497
# 2                   7351
# 3                  12415
# 4                  18698
# ..                   ...
# 328             72802789
# 329             73247510
# 330             73693578
# 331             74140994
# 332             74589756
#
# [333 rows x 1 columns]

# %%
# Data Type = Floating Point
# Upperbound Value = 10000
# Number of Maximum Inputs = 1000
plt.title("Number of operation vs n.")
plt.xlabel("Number of input, n")
plt.ylabel("Number of operation")
plt.plot(x5.to_numpy(),y5.to_numpy())
plt.show()

# %% [markdown]
# ### Experiment 6
# - Input Data Type: Floating Point
# - Random Number Upperbound: 100
# - Maximum Number of Inputs: 1000

# %%
x6= pd.read_csv('NumOfInputs-n_1000.csv')
x6
# Out:
#      Number of input, n
# 0                     3
# 1                     6
# 2                     9
# 3                    12
# 4                    15
# ..                  ...
# 328                 987
# 329                 990
# 330                 993
# 331                 996
# 332                 999
#
# [333 rows x 1 columns]

# %%
y6= pd.read_csv('NumOfOperations_fp-1000-upper100.csv')
y6
# Out:
#      Number of Operations
# 0                    1279
# 1                    3637
# 2                    7080
# 3                   11611
# 4                   17894
# ..                    ...
# 328              72806748
# 329              73251469
# 330              73697536
# 331              74144950
# 332              74593712
#
# [333 rows x 1 columns]

# %%
# Data Type = Floating Point
# Upperbound Value = 100
# Number of Maximum Inputs = 1000
plt.title("Number of operation vs n.")
plt.xlabel("Number of input, n")
plt.ylabel("Number of operation")
plt.plot(x6.to_numpy(),y6.to_numpy())
plt.show()

# %% [markdown]
# ## Relationship between number of inputs and time elapsed after performing the operations.

# %% [markdown]
# ### Experiment 7
# - Input Data Type: Integer
# - Random Number Upperbound: 10000
# - Maximum Number of Inputs: 1000

# %%
x7 = pd.read_csv("NumOfInputs-n_1000.csv")
x7
# Out:
#      Number of input, n
# 0                     3
# 1                     6
# 2                     9
# 3                    12
# 4                    15
# ..                  ...
# 328                 987
# 329                 990
# 330                 993
# 331                 996
# 332                 999
#
# [333 rows x 1 columns]

# %%
y7 = pd.read_csv("TimeElapsed_int-1000.csv")
y7
# Out:
#      Time Elapsed (ns)
# 0              4701200
# 1              5629800
# 2              6225500
# 3              6732000
# 4              7196300
# ..                 ...
# 328          525307200
# 329          526739900
# 330          527835200
# 331          530261400
# 332          530972100
#
# [333 rows x 1 columns]

# %%
# Data Type = Integer
# Upperbound Value = 10000
# Number of Maximum Inputs = 1000
plt.title("Time Elapsed vs n.")
plt.xlabel("Number of input, n")
plt.ylabel("Time Elapsed (ns)")
plt.plot(x7.to_numpy(),y7.to_numpy())
plt.show()

# %% [markdown]
# ### Experiment 8
# - Input Data Type: Floating Point
# - Random Number Upperbound: 10000
# - Maximum Number of Inputs: 1000

# %%
x8 = pd.read_csv("NumOfInputs-n_1000.csv")
x8
# Out:
#      Number of input, n
# 0                     3
# 1                     6
# 2                     9
# 3                    12
# 4                    15
# ..                  ...
# 328                 987
# 329                 990
# 330                 993
# 331                 996
# 332                 999
#
# [333 rows x 1 columns]

# %%
y8 = pd.read_csv("TimeElapsed_fp-1000.csv")
y8
# Out:
#      Time Elapsed (ms)
# 0              5667000
# 1              6766500
# 2              7924200
# 3              9441300
# 4             10386900
# ..                 ...
# 328          696636800
# 329          697891800
# 330          699149700
# 331          700398800
# 332          701822100
#
# [333 rows x 1 columns]

# %%
# Data Type = Floating Point
# Upperbound Value = 10000
# Number of Maximum Inputs = 1000
plt.title("Time Elapsed vs n.")
plt.xlabel("Number of input, n")
plt.ylabel("Time Elapsed (ns)")
plt.plot(x8.to_numpy(),y8.to_numpy())
plt.show()

# %% [markdown]
# ## Relationship Analysis

# %% [markdown]
# ### Relationship between high and low upper bound on the number of operations

# %%
# Show the comparison between high and low upperbound
# Data type: Integer
plt.title("Number of operation vs n.")
plt.xlabel("Number of input, n")
plt.ylabel("Number of operation")

plt.plot(x2.to_numpy(), y2.to_numpy(), label = "Upperbound = 10000") 
plt.plot(x3.to_numpy(), y3.to_numpy(), label = "Upperbound = 100")   
plt.legend()

plt.show()

# %%
# Show the comparison between high and low upperbound
# Data type: Floating Point
plt.title("Number of operation vs n.")
plt.xlabel("Number of input, n")
plt.ylabel("Number of operation")

plt.plot(x5.to_numpy(), y5.to_numpy(), label = "Upperbound = 10000") 
plt.plot(x6.to_numpy(), y6.to_numpy(), label = "Upperbound = 100")   
plt.legend()

plt.show()

# %% [markdown]
# From the graphs above, we can infer that the size of the upperbound, which indicates the maximum value of the randomly generated inputs, only affects the number of operations for inputs of integer data type, but not inputs of floating point data type. This is because the number of iterations in the radix sort algorithm for integers is based on the number of digits of the integer, while the number of iterations for floating points is based on the number of digits of the whole number, including both the integer places and the decimal places. For integer values, the higher the upperbond, the larger the number of operations performed.
#
# Below is a graph that illustrates the relationship for both integers and floating points.

# %%
# Show the comparison between high and low upperbound
# Data type: Integer and Floating Point
plt.title("Number of operation vs n.")
plt.xlabel("Number of input, n")
plt.ylabel("Number of operation")

plt.plot(x2.to_numpy(), y2.to_numpy(), label = "Int:Upperbound = 10000") # integer
plt.plot(x3.to_numpy(), y3.to_numpy(), label = "Int:Upperbound = 100")   # integer
plt.plot(x5.to_numpy(), y5.to_numpy(), label = "FP:Upperbound = 10000") # floating point
plt.plot(x6.to_numpy(), y6.to_numpy(), label = "FP:Upperbound = 100")   # floating point
plt.legend()

plt.show()

# %% [markdown]
# ### Relationship between different data types and the number of operations performed.

# %%
# Show the comparison between data types integer and floating point
# Number of inputs: 100
plt.title("Number of operation vs n.")
plt.xlabel("Number of input, n")
plt.ylabel("Number of operation")

plt.plot(x1.to_numpy(), y1.to_numpy(), label = "Integer") # integer
plt.plot(x4.to_numpy(), y4.to_numpy(), label = "Floating Point") # floating point
plt.legend()

plt.show()

# %%
# Show the comparison between data types integer and floating point
# Number of inputs
plt.title("Number of operation vs n.")
plt.xlabel("Number of input, n")
plt.ylabel("Number of operation")

plt.plot(x2.to_numpy(), y2.to_numpy(), label = "Integer") # integer
plt.plot(x5.to_numpy(), y5.to_numpy(), label = "Floating Point") # floating point
plt.legend()

plt.show()
